# %% [markdown]
# # Experiment No:1 Creating a NumPy Array

# %% [markdown]
# <b> Experiment No 1(A) Basic ndarray

# %%
import numpy as np

# %%
#Create a one dimesional array
arr =np.array([2,3,4])
print(arr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13720\3055092779.py in <module>
#       1 #Create a array
# ----> 2 arr =np.array([3,6,9])
#       3 print (arr)
#
# NameError: name 'np' is not defined
